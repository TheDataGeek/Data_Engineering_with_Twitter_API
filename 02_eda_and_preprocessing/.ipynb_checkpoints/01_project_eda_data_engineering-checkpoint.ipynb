# %% [markdown]
# # pip install vaderSentiment

# %%
#pip install vaderSentiment

# %%
pip show vaderSentiment
# Out:
# Name: vaderSentiment
# Version: 3.3.2
# Summary: VADER Sentiment Analysis. VADER (Valence Aware Dictionary and sEntiment Reasoner) is a lexicon and rule-based sentiment analysis tool that is specifically attuned to sentiments expressed in social media, and works well on texts from other domains.
# Home-page: https://github.com/cjhutto/vaderSentiment
# Author: C.J. Hutto
# Author-email: cjhutto@gatech.edu
# License: MIT License
# Location: /opt/conda/lib/python3.10/site-packages
# Requires: requests
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # import libraries

# %%
# eda
import pandas as pd
import numpy as np
from collections import Counter

# data handling
import pyspark 

# nlp eda
import re
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %%
spark = pyspark.sql.SparkSession.builder.getOrCreate()

# %%
df = spark.read.json('../01_data_collection/*.json')

# %%
df.printSchema()
# Out:
# root
#  |-- contributors: string (nullable = true)
#  |-- coordinates: string (nullable = true)
#  |-- created_at: string (nullable = true)
#  |-- display_text_range: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- entities: struct (nullable = true)
#  |    |-- hashtags: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |-- media: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |-- source_user_id: long (nullable = true)
#  |    |    |    |-- source_user_id_str: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- symbols: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |-- urls: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- user_mentions: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- screen_name: string (nullable = true)
#  |-- extended_entities: struct (nullable = true)
#  |    |-- media: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- additional_media_info: struct (nullable = true)
#  |    |    |    |    |-- call_to_actions: struct (nullable = true)
#  |    |    |    |    |    |-- visit_site: struct (nullable = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- embeddable: boolean (nullable = true)
#  |    |    |    |    |-- monetizable: boolean (nullable = true)
#  |    |    |    |    |-- source_user: struct (nullable = true)
#  |    |    |    |    |    |-- contributors_enabled: boolean (nullable = true)
#  |    |    |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |    |    |-- default_profile: boolean (nullable = true)
#  |    |    |    |    |    |-- default_profile_image: boolean (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- entities: struct (nullable = true)
#  |    |    |    |    |    |    |-- description: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |-- url: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- favourites_count: long (nullable = true)
#  |    |    |    |    |    |-- follow_request_sent: string (nullable = true)
#  |    |    |    |    |    |-- followers_count: long (nullable = true)
#  |    |    |    |    |    |-- following: string (nullable = true)
#  |    |    |    |    |    |-- friends_count: long (nullable = true)
#  |    |    |    |    |    |-- geo_enabled: boolean (nullable = true)
#  |    |    |    |    |    |-- has_extended_profile: boolean (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |    |-- is_translation_enabled: boolean (nullable = true)
#  |    |    |    |    |    |-- is_translator: boolean (nullable = true)
#  |    |    |    |    |    |-- lang: string (nullable = true)
#  |    |    |    |    |    |-- listed_count: long (nullable = true)
#  |    |    |    |    |    |-- location: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- notifications: string (nullable = true)
#  |    |    |    |    |    |-- profile_background_color: string (nullable = true)
#  |    |    |    |    |    |-- profile_background_image_url: string (nullable = true)
#  |    |    |    |    |    |-- profile_background_image_url_https: string (nullable = true)
#  |    |    |    |    |    |-- profile_background_tile: boolean (nullable = true)
#  |    |    |    |    |    |-- profile_banner_url: string (nullable = true)
#  |    |    |    |    |    |-- profile_image_url: string (nullable = true)
#  |    |    |    |    |    |-- profile_image_url_https: string (nullable = true)
#  |    |    |    |    |    |-- profile_link_color: string (nullable = true)
#  |    |    |    |    |    |-- profile_sidebar_border_color: string (nullable = true)
#  |    |    |    |    |    |-- profile_sidebar_fill_color: string (nullable = true)
#  |    |    |    |    |    |-- profile_text_color: string (nullable = true)
#  |    |    |    |    |    |-- profile_use_background_image: boolean (nullable = true)
#  |    |    |    |    |    |-- protected: boolean (nullable = true)
#  |    |    |    |    |    |-- screen_name: string (nullable = true)
#  |    |    |    |    |    |-- statuses_count: long (nullable = true)
#  |    |    |    |    |    |-- time_zone: string (nullable = true)
#  |    |    |    |    |    |-- translator_type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- utc_offset: string (nullable = true)
#  |    |    |    |    |    |-- verified: boolean (nullable = true)
#  |    |    |    |    |    |-- withheld_in_countries: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |-- source_user_id: long (nullable = true)
#  |    |    |    |-- source_user_id_str: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- video_info: struct (nullable = true)
#  |    |    |    |    |-- aspect_ratio: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- duration_millis: long (nullable = true)
#  |    |    |    |    |-- variants: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- bitrate: long (nullable = true)
#  |    |    |    |    |    |    |-- content_type: string (nullable = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |-- favorite_count: long (nullable = true)
#  |-- favorited: boolean (nullable = true)
#  |-- full_text: string (nullable = true)
#  |-- geo: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- id_str: string (nullable = true)
#  |-- in_reply_to_screen_name: string (nullable = true)
#  |-- in_reply_to_status_id: long (nullable = true)
#  |-- in_reply_to_status_id_str: string (nullable = true)
#  |-- in_reply_to_user_id: long (nullable = true)
#  |-- in_reply_to_user_id_str: string (nullable = true)
#  |-- is_quote_status: boolean (nullable = true)
#  |-- lang: string (nullable = true)
#  |-- metadata: struct (nullable = true)
#  |    |-- iso_language_code: string (nullable = true)
#  |    |-- result_type: string (nullable = true)
#  |-- place: struct (nullable = true)
#  |    |-- bounding_box: struct (nullable = true)
#  |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- contained_within: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- country: string (nullable = true)
#  |    |-- country_code: string (nullable = true)
#  |    |-- full_name: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- place_type: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- possibly_sensitive: boolean (nullable = true)
#  |-- quoted_status: struct (nullable = true)
#  |    |-- contributors: string (nullable = true)
#  |    |-- coordinates: string (nullable = true)
#  |    |-- created_at: string (nullable = true)
#  |    |-- display_text_range: array (nullable = true)
#  |    |    |-- element: long (containsNull = true)
#  |    |-- entities: struct (nullable = true)
#  |    |    |-- hashtags: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |-- media: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |    |-- source_user_id: long (nullable = true)
#  |    |    |    |    |-- source_user_id_str: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- symbols: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- urls: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- user_mentions: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- screen_name: string (nullable = true)
#  |    |-- extended_entities: struct (nullable = true)
#  |    |    |-- media: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- additional_media_info: struct (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- embeddable: boolean (nullable = true)
#  |    |    |    |    |    |-- monetizable: boolean (nullable = true)
#  |    |    |    |    |    |-- source_user: struct (nullable = true)
#  |    |    |    |    |    |    |-- contributors_enabled: boolean (nullable = true)
#  |    |    |    |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |    |    |    |-- default_profile: boolean (nullable = true)
#  |    |    |    |    |    |    |-- default_profile_image: boolean (nullable = true)
#  |    |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |    |-- entities: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- description: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |-- favourites_count: long (nullable = true)
#  |    |    |    |    |    |    |-- follow_request_sent: string (nullable = true)
#  |    |    |    |    |    |    |-- followers_count: long (nullable = true)
#  |    |    |    |    |    |    |-- following: string (nullable = true)
#  |    |    |    |    |    |    |-- friends_count: long (nullable = true)
#  |    |    |    |    |    |    |-- geo_enabled: boolean (nullable = true)
#  |    |    |    |    |    |    |-- has_extended_profile: boolean (nullable = true)
#  |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |    |    |-- is_translation_enabled: boolean (nullable = true)
#  |    |    |    |    |    |    |-- is_translator: boolean (nullable = true)
#  |    |    |    |    |    |    |-- lang: string (nullable = true)
#  |    |    |    |    |    |    |-- listed_count: long (nullable = true)
#  |    |    |    |    |    |    |-- location: string (nullable = true)
#  |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |-- notifications: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_background_color: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_background_image_url: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_background_image_url_https: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_background_tile: boolean (nullable = true)
#  |    |    |    |    |    |    |-- profile_image_url: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_image_url_https: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_link_color: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_sidebar_border_color: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_sidebar_fill_color: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_text_color: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_use_background_image: boolean (nullable = true)
#  |    |    |    |    |    |    |-- protected: boolean (nullable = true)
#  |    |    |    |    |    |    |-- screen_name: string (nullable = true)
#  |    |    |    |    |    |    |-- statuses_count: long (nullable = true)
#  |    |    |    |    |    |    |-- time_zone: string (nullable = true)
#  |    |    |    |    |    |    |-- translator_type: string (nullable = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |-- utc_offset: string (nullable = true)
#  |    |    |    |    |    |    |-- verified: boolean (nullable = true)
#  |    |    |    |    |    |    |-- withheld_in_countries: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |    |-- source_user_id: long (nullable = true)
#  |    |    |    |    |-- source_user_id_str: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- video_info: struct (nullable = true)
#  |    |    |    |    |    |-- aspect_ratio: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- duration_millis: long (nullable = true)
#  |    |    |    |    |    |-- variants: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- bitrate: long (nullable = true)
#  |    |    |    |    |    |    |    |-- content_type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |-- favorite_count: long (nullable = true)
#  |    |-- favorited: boolean (nullable = true)
#  |    |-- full_text: string (nullable = true)
#  |    |-- geo: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- id_str: string (nullable = true)
#  |    |-- in_reply_to_screen_name: string (nullable = true)
#  |    |-- in_reply_to_status_id: long (nullable = true)
#  |    |-- in_reply_to_status_id_str: string (nullable = true)
#  |    |-- in_reply_to_user_id: long (nullable = true)
#  |    |-- in_reply_to_user_id_str: string (nullable = true)
#  |    |-- is_quote_status: boolean (nullable = true)
#  |    |-- lang: string (nullable = true)
#  |    |-- metadata: struct (nullable = true)
#  |    |    |-- iso_language_code: string (nullable = true)
#  |    |    |-- result_type: string (nullable = true)
#  |    |-- place: string (nullable = true)
#  |    |-- possibly_sensitive: boolean (nullable = true)
#  |    |-- quoted_status_id: long (nullable = true)
#  |    |-- quoted_status_id_str: string (nullable = true)
#  |    |-- retweet_count: long (nullable = true)
#  |    |-- retweeted: boolean (nullable = true)
#  |    |-- scopes: struct (nullable = true)
#  |    |    |-- followers: boolean (nullable = true)
#  |    |-- source: string (nullable = true)
#  |    |-- truncated: boolean (nullable = true)
#  |    |-- user: struct (nullable = true)
#  |    |    |-- contributors_enabled: boolean (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- default_profile: boolean (nullable = true)
#  |    |    |-- default_profile_image: boolean (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- entities: struct (nullable = true)
#  |    |    |    |-- description: struct (nullable = true)
#  |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- url: struct (nullable = true)
#  |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- favourites_count: long (nullable = true)
#  |    |    |-- follow_request_sent: string (nullable = true)
#  |    |    |-- followers_count: long (nullable = true)
#  |    |    |-- following: string (nullable = true)
#  |    |    |-- friends_count: long (nullable = true)
#  |    |    |-- geo_enabled: boolean (nullable = true)
#  |    |    |-- has_extended_profile: boolean (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- id_str: string (nullable = true)
#  |    |    |-- is_translation_enabled: boolean (nullable = true)
#  |    |    |-- is_translator: boolean (nullable = true)
#  |    |    |-- lang: string (nullable = true)
#  |    |    |-- listed_count: long (nullable = true)
#  |    |    |-- location: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- notifications: string (nullable = true)
#  |    |    |-- profile_background_color: string (nullable = true)
#  |    |    |-- profile_background_image_url: string (nullable = true)
#  |    |    |-- profile_background_image_url_https: string (nullable = true)
#  |    |    |-- profile_background_tile: boolean (nullable = true)
#  |    |    |-- profile_banner_url: string (nullable = true)
#  |    |    |-- profile_image_url: string (nullable = true)
#  |    |    |-- profile_image_url_https: string (nullable = true)
#  |    |    |-- profile_link_color: string (nullable = true)
#  |    |    |-- profile_sidebar_border_color: string (nullable = true)
#  |    |    |-- profile_sidebar_fill_color: string (nullable = true)
#  |    |    |-- profile_text_color: string (nullable = true)
#  |    |    |-- profile_use_background_image: boolean (nullable = true)
#  |    |    |-- protected: boolean (nullable = true)
#  |    |    |-- screen_name: string (nullable = true)
#  |    |    |-- statuses_count: long (nullable = true)
#  |    |    |-- time_zone: string (nullable = true)
#  |    |    |-- translator_type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- utc_offset: string (nullable = true)
#  |    |    |-- verified: boolean (nullable = true)
#  |    |    |-- withheld_in_countries: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |-- quoted_status_id: long (nullable = true)
#  |-- quoted_status_id_str: string (nullable = true)
#  |-- retweet_count: long (nullable = true)
#  |-- retweeted: boolean (nullable = true)
#  |-- retweeted_status: struct (nullable = true)
#  |    |-- contributors: string (nullable = true)
#  |    |-- coordinates: string (nullable = true)
#  |    |-- created_at: string (nullable = true)
#  |    |-- display_text_range: array (nullable = true)
#  |    |    |-- element: long (containsNull = true)
#  |    |-- entities: struct (nullable = true)
#  |    |    |-- hashtags: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |-- media: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |    |-- source_user_id: long (nullable = true)
#  |    |    |    |    |-- source_user_id_str: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- symbols: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |-- urls: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- user_mentions: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- screen_name: string (nullable = true)
#  |    |-- extended_entities: struct (nullable = true)
#  |    |    |-- media: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- additional_media_info: struct (nullable = true)
#  |    |    |    |    |    |-- call_to_actions: struct (nullable = true)
#  |    |    |    |    |    |    |-- visit_site: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- embeddable: boolean (nullable = true)
#  |    |    |    |    |    |-- monetizable: boolean (nullable = true)
#  |    |    |    |    |    |-- source_user: struct (nullable = true)
#  |    |    |    |    |    |    |-- contributors_enabled: boolean (nullable = true)
#  |    |    |    |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |    |    |    |-- default_profile: boolean (nullable = true)
#  |    |    |    |    |    |    |-- default_profile_image: boolean (nullable = true)
#  |    |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |    |-- entities: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- description: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |-- url: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |-- favourites_count: long (nullable = true)
#  |    |    |    |    |    |    |-- follow_request_sent: string (nullable = true)
#  |    |    |    |    |    |    |-- followers_count: long (nullable = true)
#  |    |    |    |    |    |    |-- following: string (nullable = true)
#  |    |    |    |    |    |    |-- friends_count: long (nullable = true)
#  |    |    |    |    |    |    |-- geo_enabled: boolean (nullable = true)
#  |    |    |    |    |    |    |-- has_extended_profile: boolean (nullable = true)
#  |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |    |    |-- is_translation_enabled: boolean (nullable = true)
#  |    |    |    |    |    |    |-- is_translator: boolean (nullable = true)
#  |    |    |    |    |    |    |-- lang: string (nullable = true)
#  |    |    |    |    |    |    |-- listed_count: long (nullable = true)
#  |    |    |    |    |    |    |-- location: string (nullable = true)
#  |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |-- notifications: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_background_color: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_background_image_url: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_background_image_url_https: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_background_tile: boolean (nullable = true)
#  |    |    |    |    |    |    |-- profile_banner_url: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_image_url: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_image_url_https: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_link_color: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_sidebar_border_color: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_sidebar_fill_color: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_text_color: string (nullable = true)
#  |    |    |    |    |    |    |-- profile_use_background_image: boolean (nullable = true)
#  |    |    |    |    |    |    |-- protected: boolean (nullable = true)
#  |    |    |    |    |    |    |-- screen_name: string (nullable = true)
#  |    |    |    |    |    |    |-- statuses_count: long (nullable = true)
#  |    |    |    |    |    |    |-- time_zone: string (nullable = true)
#  |    |    |    |    |    |    |-- translator_type: string (nullable = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |-- utc_offset: string (nullable = true)
#  |    |    |    |    |    |    |-- verified: boolean (nullable = true)
#  |    |    |    |    |    |    |-- withheld_in_countries: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |    |-- source_user_id: long (nullable = true)
#  |    |    |    |    |-- source_user_id_str: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- video_info: struct (nullable = true)
#  |    |    |    |    |    |-- aspect_ratio: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- duration_millis: long (nullable = true)
#  |    |    |    |    |    |-- variants: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- bitrate: long (nullable = true)
#  |    |    |    |    |    |    |    |-- content_type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |-- favorite_count: long (nullable = true)
#  |    |-- favorited: boolean (nullable = true)
#  |    |-- full_text: string (nullable = true)
#  |    |-- geo: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- id_str: string (nullable = true)
#  |    |-- in_reply_to_screen_name: string (nullable = true)
#  |    |-- in_reply_to_status_id: long (nullable = true)
#  |    |-- in_reply_to_status_id_str: string (nullable = true)
#  |    |-- in_reply_to_user_id: long (nullable = true)
#  |    |-- in_reply_to_user_id_str: string (nullable = true)
#  |    |-- is_quote_status: boolean (nullable = true)
#  |    |-- lang: string (nullable = true)
#  |    |-- metadata: struct (nullable = true)
#  |    |    |-- iso_language_code: string (nullable = true)
#  |    |    |-- result_type: string (nullable = true)
#  |    |-- place: struct (nullable = true)
#  |    |    |-- bounding_box: struct (nullable = true)
#  |    |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- contained_within: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- country: string (nullable = true)
#  |    |    |-- country_code: string (nullable = true)
#  |    |    |-- full_name: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- place_type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |-- possibly_sensitive: boolean (nullable = true)
#  |    |-- quoted_status: struct (nullable = true)
#  |    |    |-- contributors: string (nullable = true)
#  |    |    |-- coordinates: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- display_text_range: array (nullable = true)
#  |    |    |    |-- element: long (containsNull = true)
#  |    |    |-- entities: struct (nullable = true)
#  |    |    |    |-- hashtags: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- media: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |    |    |-- source_user_id: long (nullable = true)
#  |    |    |    |    |    |-- source_user_id_str: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- symbols: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- user_mentions: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- screen_name: string (nullable = true)
#  |    |    |-- extended_entities: struct (nullable = true)
#  |    |    |    |-- media: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- additional_media_info: struct (nullable = true)
#  |    |    |    |    |    |    |-- call_to_actions: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- visit_site: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- watch_now: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |    |-- embeddable: boolean (nullable = true)
#  |    |    |    |    |    |    |-- monetizable: boolean (nullable = true)
#  |    |    |    |    |    |    |-- source_user: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- contributors_enabled: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |    |    |    |    |-- default_profile: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- default_profile_image: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |    |    |-- entities: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- description: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |-- favourites_count: long (nullable = true)
#  |    |    |    |    |    |    |    |-- follow_request_sent: string (nullable = true)
#  |    |    |    |    |    |    |    |-- followers_count: long (nullable = true)
#  |    |    |    |    |    |    |    |-- following: string (nullable = true)
#  |    |    |    |    |    |    |    |-- friends_count: long (nullable = true)
#  |    |    |    |    |    |    |    |-- geo_enabled: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- has_extended_profile: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |    |    |    |-- is_translation_enabled: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- is_translator: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- lang: string (nullable = true)
#  |    |    |    |    |    |    |    |-- listed_count: long (nullable = true)
#  |    |    |    |    |    |    |    |-- location: string (nullable = true)
# ...
#  |    |    |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |    |    |-- source_user_id: long (nullable = true)
#  |    |    |    |    |    |-- source_user_id_str: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- video_info: struct (nullable = true)
#  |    |    |    |    |    |    |-- aspect_ratio: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |    |-- duration_millis: long (nullable = true)
#  |    |    |    |    |    |    |-- variants: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- bitrate: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- content_type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- favorite_count: long (nullable = true)
#  |    |    |-- favorited: boolean (nullable = true)
#  |    |    |-- full_text: string (nullable = true)
#  |    |    |-- geo: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- id_str: string (nullable = true)
#  |    |    |-- in_reply_to_screen_name: string (nullable = true)
#  |    |    |-- in_reply_to_status_id: long (nullable = true)
#  |    |    |-- in_reply_to_status_id_str: string (nullable = true)
#  |    |    |-- in_reply_to_user_id: long (nullable = true)
#  |    |    |-- in_reply_to_user_id_str: string (nullable = true)
#  |    |    |-- is_quote_status: boolean (nullable = true)
#  |    |    |-- lang: string (nullable = true)
#  |    |    |-- metadata: struct (nullable = true)
#  |    |    |    |-- iso_language_code: string (nullable = true)
#  |    |    |    |-- result_type: string (nullable = true)
#  |    |    |-- place: struct (nullable = true)
#  |    |    |    |-- bounding_box: struct (nullable = true)
#  |    |    |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- contained_within: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- country: string (nullable = true)
#  |    |    |    |-- country_code: string (nullable = true)
#  |    |    |    |-- full_name: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- place_type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- possibly_sensitive: boolean (nullable = true)
#  |    |    |-- quoted_status_id: long (nullable = true)
#  |    |    |-- quoted_status_id_str: string (nullable = true)
#  |    |    |-- retweet_count: long (nullable = true)
#  |    |    |-- retweeted: boolean (nullable = true)
#  |    |    |-- source: string (nullable = true)
#  |    |    |-- truncated: boolean (nullable = true)
#  |    |    |-- user: struct (nullable = true)
#  |    |    |    |-- contributors_enabled: boolean (nullable = true)
#  |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |-- default_profile: boolean (nullable = true)
#  |    |    |    |-- default_profile_image: boolean (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- entities: struct (nullable = true)
#  |    |    |    |    |-- description: struct (nullable = true)
#  |    |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- url: struct (nullable = true)
#  |    |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- favourites_count: long (nullable = true)
#  |    |    |    |-- follow_request_sent: string (nullable = true)
#  |    |    |    |-- followers_count: long (nullable = true)
#  |    |    |    |-- following: string (nullable = true)
#  |    |    |    |-- friends_count: long (nullable = true)
#  |    |    |    |-- geo_enabled: boolean (nullable = true)
#  |    |    |    |-- has_extended_profile: boolean (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |-- is_translation_enabled: boolean (nullable = true)
#  |    |    |    |-- is_translator: boolean (nullable = true)
#  |    |    |    |-- lang: string (nullable = true)
#  |    |    |    |-- listed_count: long (nullable = true)
#  |    |    |    |-- location: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- notifications: string (nullable = true)
#  |    |    |    |-- profile_background_color: string (nullable = true)
#  |    |    |    |-- profile_background_image_url: string (nullable = true)
#  |    |    |    |-- profile_background_image_url_https: string (nullable = true)
#  |    |    |    |-- profile_background_tile: boolean (nullable = true)
#  |    |    |    |-- profile_banner_url: string (nullable = true)
#  |    |    |    |-- profile_image_url: string (nullable = true)
#  |    |    |    |-- profile_image_url_https: string (nullable = true)
#  |    |    |    |-- profile_link_color: string (nullable = true)
#  |    |    |    |-- profile_sidebar_border_color: string (nullable = true)
#  |    |    |    |-- profile_sidebar_fill_color: string (nullable = true)
#  |    |    |    |-- profile_text_color: string (nullable = true)
#  |    |    |    |-- profile_use_background_image: boolean (nullable = true)
#  |    |    |    |-- protected: boolean (nullable = true)
#  |    |    |    |-- screen_name: string (nullable = true)
#  |    |    |    |-- statuses_count: long (nullable = true)
#  |    |    |    |-- time_zone: string (nullable = true)
#  |    |    |    |-- translator_type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- utc_offset: string (nullable = true)
#  |    |    |    |-- verified: boolean (nullable = true)
#  |    |    |    |-- withheld_in_countries: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |-- quoted_status_id: long (nullable = true)
#  |    |-- quoted_status_id_str: string (nullable = true)
#  |    |-- retweet_count: long (nullable = true)
#  |    |-- retweeted: boolean (nullable = true)
#  |    |-- scopes: struct (nullable = true)
#  |    |    |-- followers: boolean (nullable = true)
#  |    |-- source: string (nullable = true)
#  |    |-- truncated: boolean (nullable = true)
#  |    |-- user: struct (nullable = true)
#  |    |    |-- contributors_enabled: boolean (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- default_profile: boolean (nullable = true)
#  |    |    |-- default_profile_image: boolean (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- entities: struct (nullable = true)
#  |    |    |    |-- description: struct (nullable = true)
#  |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- url: struct (nullable = true)
#  |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- favourites_count: long (nullable = true)
#  |    |    |-- follow_request_sent: string (nullable = true)
#  |    |    |-- followers_count: long (nullable = true)
#  |    |    |-- following: string (nullable = true)
#  |    |    |-- friends_count: long (nullable = true)
#  |    |    |-- geo_enabled: boolean (nullable = true)
#  |    |    |-- has_extended_profile: boolean (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- id_str: string (nullable = true)
#  |    |    |-- is_translation_enabled: boolean (nullable = true)
#  |    |    |-- is_translator: boolean (nullable = true)
#  |    |    |-- lang: string (nullable = true)
#  |    |    |-- listed_count: long (nullable = true)
#  |    |    |-- location: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- notifications: string (nullable = true)
#  |    |    |-- profile_background_color: string (nullable = true)
#  |    |    |-- profile_background_image_url: string (nullable = true)
#  |    |    |-- profile_background_image_url_https: string (nullable = true)
#  |    |    |-- profile_background_tile: boolean (nullable = true)
#  |    |    |-- profile_banner_url: string (nullable = true)
#  |    |    |-- profile_image_url: string (nullable = true)
#  |    |    |-- profile_image_url_https: string (nullable = true)
#  |    |    |-- profile_link_color: string (nullable = true)
#  |    |    |-- profile_sidebar_border_color: string (nullable = true)
#  |    |    |-- profile_sidebar_fill_color: string (nullable = true)
#  |    |    |-- profile_text_color: string (nullable = true)
#  |    |    |-- profile_use_background_image: boolean (nullable = true)
#  |    |    |-- protected: boolean (nullable = true)
#  |    |    |-- screen_name: string (nullable = true)
#  |    |    |-- statuses_count: long (nullable = true)
#  |    |    |-- time_zone: string (nullable = true)
#  |    |    |-- translator_type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- utc_offset: string (nullable = true)
#  |    |    |-- verified: boolean (nullable = true)
#  |    |    |-- withheld_in_countries: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |-- source: string (nullable = true)
#  |-- truncated: boolean (nullable = true)
#  |-- user: struct (nullable = true)
#  |    |-- contributors_enabled: boolean (nullable = true)
#  |    |-- created_at: string (nullable = true)
#  |    |-- default_profile: boolean (nullable = true)
#  |    |-- default_profile_image: boolean (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- entities: struct (nullable = true)
#  |    |    |-- description: struct (nullable = true)
#  |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- url: struct (nullable = true)
#  |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |-- favourites_count: long (nullable = true)
#  |    |-- follow_request_sent: string (nullable = true)
#  |    |-- followers_count: long (nullable = true)
#  |    |-- following: string (nullable = true)
#  |    |-- friends_count: long (nullable = true)
#  |    |-- geo_enabled: boolean (nullable = true)
#  |    |-- has_extended_profile: boolean (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- id_str: string (nullable = true)
#  |    |-- is_translation_enabled: boolean (nullable = true)
#  |    |-- is_translator: boolean (nullable = true)
#  |    |-- lang: string (nullable = true)
#  |    |-- listed_count: long (nullable = true)
#  |    |-- location: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- notifications: string (nullable = true)
#  |    |-- profile_background_color: string (nullable = true)
#  |    |-- profile_background_image_url: string (nullable = true)
#  |    |-- profile_background_image_url_https: string (nullable = true)
#  |    |-- profile_background_tile: boolean (nullable = true)
#  |    |-- profile_banner_url: string (nullable = true)
#  |    |-- profile_image_url: string (nullable = true)
#  |    |-- profile_image_url_https: string (nullable = true)
#  |    |-- profile_link_color: string (nullable = true)
#  |    |-- profile_sidebar_border_color: string (nullable = true)
#  |    |-- profile_sidebar_fill_color: string (nullable = true)
#  |    |-- profile_text_color: string (nullable = true)
#  |    |-- profile_use_background_image: boolean (nullable = true)
#  |    |-- protected: boolean (nullable = true)
#  |    |-- screen_name: string (nullable = true)
#  |    |-- statuses_count: long (nullable = true)
#  |    |-- time_zone: string (nullable = true)
#  |    |-- translator_type: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |    |-- utc_offset: string (nullable = true)
#  |    |-- verified: boolean (nullable = true)
#  |    |-- withheld_in_countries: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |-- withheld_in_countries: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %%
df.createOrReplaceTempView('df')

# %%
from pyspark.sql.functions import countDistinct

# %%
# how many distinct tweets:
tweet_unique_id = spark.sql('''
                                SELECT
                                    id_str as tweet_unique_id
                                FROM
                                    df
                                WHERE 
                                    retweeted_status.id_str IS NULL
                                                                    ''')

tweet_unique_id.select(countDistinct('tweet_unique_id')).show()
# Out:
# +-------------------------------+
# |count(DISTINCT tweet_unique_id)|
# +-------------------------------+
# |                           1292|
# +-------------------------------+

# %%
# how many distinct users:
user_unique_id = spark.sql('''
                                SELECT
                                    user.id_str as user_unique_id
                                FROM
                                    df
                                WHERE 
                                    retweeted_status.id_str IS NULL
                                                                    ''')

user_unique_id.select(countDistinct('user_unique_id')).show()
# Out:
# +------------------------------+
# |count(DISTINCT user_unique_id)|
# +------------------------------+
# |                          1170|
# +------------------------------+

# %%
sample_climate_tweets = spark.sql('''
                                    SELECT 
                                        full_text as tweet_text
                                    FROM
                                        df
                                     WHERE
                                         full_text like '%climate change%'
                                                                            ''').take(10)

sample_climate_tweets
# Out:
# [Row(tweet_text='RT @Rythmol81: Florida has 150 hurricanes since 1850 but only the recent 2 were caused by climate change!'),
#  Row(tweet_text='RT @sovietblobfish: personally i think we could try halting climate change rather than trying to turn an island nation into a fucking nft h…'),
#  Row(tweet_text='@GerberKawasaki @elonmusk Many fear everything after the 4th grade.its why we have climate change deniers and anti science politicians still promoting Fossil Fuel for their donnors.'),
#  Row(tweet_text='RT @Angelo4justice3: One thing is certain :\nIt was NEVER about climate change and ecology.\nEU is back to using coal and dirty LNG gas from…'),
#  Row(tweet_text='RT @sovietblobfish: personally i think we could try halting climate change rather than trying to turn an island nation into a fucking nft h…'),
#  Row(tweet_text='RT @climatecouncil: "You can\'t deal with existential climate change while also opening new (coal and gas) projects."  - @PatsKarvelas @RNBr…'),
#  Row(tweet_text='sometimes i wonder if these water &amp; hurricanes events is these Elites mocking God wen he sed no Flood 🤔 &amp; labeling tha fire as “climate change”'),
#  Row(tweet_text="Drought and climate change are changing the way people think about the Colorado River. Join @socalwatercomm's free webinar on Oct. 6 to learn more about what water agencies, tribes and others are doing to address this crisis. Visit https://t.co/UpEAfmNdfa to reserve your spot! https://t.co/J9Wjm2NilX"),
#  Row(tweet_text='RT @sayitnspinit: Do any of you moronic climate change con artist asshole fools want to know a secret? Hurricanes, blizzards, tornadoes, &amp;…'),
#  Row(tweet_text='@sayitnspinit Sigh. That’s NOT what climate change posits. How are you guys this stupid? I mean wow. Bring an idiot then calling others stupid bc YOU don’t understand how it works. I could try and explain it to you but I’m not you know how “the people” get inside your TV.')]

# %%
sample_global_tweets = spark.sql('''
                                    SELECT 
                                        full_text as tweet_text
                                    FROM
                                        df
                                     WHERE
                                         full_text like '%global warming%'
                                                                        ''').take(10)

sample_global_tweets
# Out:
# [Row(tweet_text="RT @NCefx: @SpryOld @emmagmay I'm sure none of the large financial services companies have any doubts that global warming/climate change is…"),
#  Row(tweet_text='Climate change is not "Man Made" Giving Liberals money to fix global warming is nonsense There stealing our money to fix nothing and making themselves rich'),
#  Row(tweet_text='@GOP In this GLOBAL inflation caused by pandemic, Russian war, and global warming, the GOP is on the wrong side of every issue. Your last 3 presidents ran up the deficit and the last 3 Dems lowered it!'),
#  Row(tweet_text='@ShelbyKStewart @SenRonJohnson \nWhat kind of an accountant denies science and global warming.  One would think it takes some brains to be an accountant.  Apparently not.'),
#  Row(tweet_text='@persisting2017 @GoncharenkoUa @elonmusk Lol. He lives in a 50k tiny house, owns practically nothing, so he can push forward electric cars to try tackle global warming. Bought Twitter to enable true freedom of speech, but yeah. Greed.😂🙄\n\nDo your homework.  Start with my pinned tweets.'),
#  Row(tweet_text="@MRobertsQLD Oh FFS Mal. Have we got to pull you up yet again. The term is global warming so a cold snap in Brisbane is not relevant now or any other time. That's simply a bit of weather."),
#  Row(tweet_text='@ByYourLogic Moral of the story if you played football, fought in mma, lied about you ownerships, academic acbievements, children out of wedlock, talk about global warming and Jesus l in the same convuluted sentences, yes you too can be the g.o.p nominee for Senate in Georgia.'),
#  Row(tweet_text="RT @UNEP: It's critical to limit global warming to 1.5°C to avoid catastrophic consequences of #ClimateChange. \n\nSolutions such as conservi…"),
#  Row(tweet_text="@Weather_West @ecologyofgavin Let's nuke a super volcano that'll solve global warming &amp; end life as we know it. https://t.co/uw98Jk7NIk"),
#  Row(tweet_text="RT @DrEliDavid: And if a small nuclear war won't flatten the global warming curve, we will need period boosters 🤡 https://t.co/akmyYwmbHX")]

# %%
# most retweeted tweet
most_retweeted = spark.sql('''
                                SELECT
                                    user.screen_name as user_twitter_handle,
                                    full_text as tweet_text,
                                    SUM(retweet_count) as total_retweets
                                FROM
                                    df
                                WHERE
                                    retweeted_status.id_str IS NULL
                                GROUP BY
                                    user_twitter_handle,
                                    tweet_text
                                ORDER BY
                                    total_retweets DESC
                                LIMIT 20
                                                        ''')

# %%
most_retweeted.show()
# Out:
# +-------------------+--------------------+--------------+
# |user_twitter_handle|          tweet_text|total_retweets|
# +-------------------+--------------------+--------------+
# |        GeorgeTakei|Go get 'em, Bill!...|            65|
# |       CarlosGSmith|As Floridians, we...|            58|
# |     davenewworld_2|According to a ne...|            41|
# |        DarcyAmaroo|Why are Conservat...|            28|
# |      Thom_Hartmann|Why This Florida ...|            16|
# |         AstroByMax|Saturn in Aquariu...|            12|
# |     davenewworld_2|"Of $17.2bn that ...|            11|
# |        adamconover|If you live on LA...|            11|
# |         TyTheFisch|If it’s “natural”...|            10|
# |        DavidPocock|Stage 3 Tax cuts ...|             9|
# |       GeraldKutney|Remember ... we m...|             8|
# |     washingtonpost|Perspective: Beef...|             8|
# |      OurRevolution|Tax Big Oil and m...|             8|
# |    ActOnClimateVic|‘The coalition sp...|             8|
# |       ClimatePower|MAGA Republicans ...|             7|
# |    factcheckdotorg|VP Kamala Harris ...|             6|
# |       govt_corrupt|@JustinTrudeau @r...|             6|
# |         jaycee1001|I really, REALLY ...|             6|
# |         Greenpeace|🌊 The oceans are...|             6|
# |     sovietblobfish|personally i thin...|             5|
# +-------------------+--------------------+--------------+

# %%
most_retweeted_df = most_retweeted.toPandas()

# %%
most_retweeted_df['tweet_text'][0]
# Out:
# "Go get 'em, Bill! https://t.co/F8LWGuwj0X"

# %%
# users with most followers
most_followers = spark.sql('''
                                SELECT
                                    user.screen_name as user_twitter_handle,
                                    MAX(user.followers_count) as max_user_followers
                                FROM
                                    df
                                GROUP BY
                                    user_twitter_handle
                                ORDER BY
                                    max_user_followers DESC
                                LIMIT 20
                                                        ''')

# %%
most_followers.show()
# Out:
# +-------------------+------------------+
# |user_twitter_handle|max_user_followers|
# +-------------------+------------------+
# |     washingtonpost|          19902336|
# |        Independent|           3663039|
# |        GeorgeTakei|           3469932|
# |       DineshDSouza|           2482122|
# |       TOIIndiaNews|           1938753|
# |         Greenpeace|           1919426|
# |     ReutersScience|            999605|
# |     PeterMcCormack|            501620|
# |         EpochTimes|            494306|
# |        QasimRashid|            352990|
# |       CTVVancouver|            347745|
# |       ClimateHuman|            319755|
# |       TexasTribune|            319103|
# |        AaronParnas|            309456|
# |           mcspocky|            293793|
# |            bqprime|            291333|
# |     MOCAlosangeles|            265009|
# |       ClimatePower|            245550|
# |     davenewworld_2|            245428|
# |        adamconover|            220985|
# +-------------------+------------------+

# %%
most_followers_df = most_followers.toPandas()
most_followers_df
# Out:
#    user_twitter_handle  max_user_followers
# 0       washingtonpost            19902336
# 1          Independent             3663039
# 2          GeorgeTakei             3469932
# 3         DineshDSouza             2482122
# 4         TOIIndiaNews             1938753
# 5           Greenpeace             1919426
# 6       ReutersScience              999605
# 7       PeterMcCormack              501620
# 8           EpochTimes              494306
# 9          QasimRashid              352990
# 10        CTVVancouver              347745
# 11        ClimateHuman              319755
# 12        TexasTribune              319103
# 13         AaronParnas              309456
# 14            mcspocky              293793
# 15             bqprime              291333
# 16      MOCAlosangeles              265009
# 17        ClimatePower              245550
# 18      davenewworld_2              245428
# 19         adamconover              220985

# %%
# most_user_mentions
user_mentions = spark.sql('''
            SELECT
                entities.user_mentions.screen_name as tweet_mentioned_user_twitter_handle
            FROM
                df
                    ''')

# %%
user_mentions.show(20)
# Out:
# +-----------------------------------+
# |tweet_mentioned_user_twitter_handle|
# +-----------------------------------+
# |                   [davenewworld_2]|
# |                        [Rythmol81]|
# |                             [NRDC]|
# |                        [nanditab1]|
# |                  [liz_churchill1_]|
# |                   [TiffanyJButler]|
# |                                 []|
# |                   [sovietblobfish]|
# |               [GerberKawasaki, ...|
# |                  [Angelo4justice3]|
# |                            [POTUS]|
# |               [EllenRosenblum, ...|
# |                         [JMM_2020]|
# |                   [sovietblobfish]|
# |               [climatecouncil, ...|
# |                                 []|
# |                            [POTUS]|
# |                  [naturesvault_io]|
# |                   [SoCalWaterComm]|
# |                      [nowthisnews]|
# +-----------------------------------+
# only showing top 20 rows

# %%
user_mentions.count()
# Out:
# 5081

# %%
user_mentions_list = []
for mentions in user_mentions.collect():
    for obj in mentions['tweet_mentioned_user_twitter_handle']:
        user_mentions_list.append(obj)

# %%
user_mentions_list[0:10]
# Out:
# ['davenewworld_2',
#  'Rythmol81',
#  'NRDC',
#  'nanditab1',
#  'liz_churchill1_',
#  'TiffanyJButler',
#  'sovietblobfish',
#  'GerberKawasaki',
#  'elonmusk',
#  'Angelo4justice3']

# %%
len(user_mentions_list)
# Out:
# 6523

# %%
most_common_mentions = Counter(user_mentions_list).most_common(20)
most_common_mentions
# Out:
# [('nanditab1', 371),
#  ('POTUS', 345),
#  ('naturesvault_io', 192),
#  ('JustStop_Oil', 176),
#  ('cameraZoe', 163),
#  ('benshapiro', 102),
#  ('TonyHussein4', 86),
#  ('MikeHudema', 80),
#  ('AndrewJBates46', 72),
#  ('PolitiFact', 70),
#  ('davenewworld_2', 58),
#  ('JoJoFromJerz', 58),
#  ('CarlosGSmith', 58),
#  ('GeorgeTakei', 54),
#  ('ClimateHuman', 53),
#  ('sayitnspinit', 44),
#  ('PeterDClack', 44),
#  ('liz_churchill1_', 41),
#  ('EmaanzT', 33),
#  ('disclosetv', 33)]

# %%
most_user_mentions = pd.DataFrame(most_common_mentions, columns=[['user_name','mentions']])
most_user_mentions
# Out:
#           user_name mentions
# 0         nanditab1      371
# 1             POTUS      345
# 2   naturesvault_io      192
# 3      JustStop_Oil      176
# 4         cameraZoe      163
# 5        benshapiro      102
# 6      TonyHussein4       86
# 7        MikeHudema       80
# 8    AndrewJBates46       72
# 9        PolitiFact       70
# 10   davenewworld_2       58
# 11     JoJoFromJerz       58
# 12     CarlosGSmith       58
# 13      GeorgeTakei       54
# 14     ClimateHuman       53
# 15     sayitnspinit       44
# 16      PeterDClack       44
# 17  liz_churchill1_       41
# 18          EmaanzT       33
# 19       disclosetv       33

# %%
# tweets from most common location
user_location = spark.sql('''
                            SELECT
                                user.location as user_location
                            FROM
                                df
                            WHERE 
                                retweeted_status.id_str IS NULL    
                                                                ''')

# %%
user_location.show(20)
# Out:
# +--------------------+
# |       user_location|
# +--------------------+
# |Skwxwú7mesh, səl̓...|
# |                    |
# | Southern California|
# |Realm Not Yet Dis...|
# |        Imperial, CA|
# |              Helena|
# |          Austin, TX|
# |              Swamp |
# |Great Commonwealt...|
# |        Murdochistan|
# |        Billings, MT|
# |                    |
# |      Cornwall, U.K.|
# |                    |
# |     Dopamine Island|
# |                    |
# |             El Paso|
# |           Singapore|
# |         Concord, NH|
# |                    |
# +--------------------+
# only showing top 20 rows

# %%
user_location.count()
# Out:
# 1292

# %%
user_location_list = []
for location in user_location.collect():
    user_location_list.append(location['user_location'])

# %%
user_location_list[0:10]
# Out:
# ['Skwxwú7mesh, səl̓ilwətaɁɬ land',
#  '',
#  'Southern California',
#  'Realm Not Yet Disclosed',
#  'Imperial, CA',
#  'Helena',
#  'Austin, TX',
#  ' Swamp ',
#  'Great Commonwealth of Virginia',
#  'Murdochistan']

# %%
len(user_location_list)
# Out:
# 1292

# %%
most_common_locations = Counter(user_location_list).most_common(20)
most_common_locations
# Out:
# [('', 485),
#  ('United States', 24),
#  ('Los Angeles, CA', 15),
#  ('Earth', 10),
#  ('New Zealand', 9),
#  ('Canada', 9),
#  ('New Jersey, USA', 9),
#  ('Vancouver, British Columbia', 8),
#  ('USA', 7),
#  ("Your Motherboard's house", 6),
#  ('Earth Between Mexico & Canada ', 6),
#  ('Australia', 6),
#  ('California, USA', 6),
#  ('Florida, USA', 5),
#  ('Michigan, USA', 5),
#  ('London', 5),
#  ('Harrow  and Brighton England', 5),
#  ('New York City', 5),
#  ('UK', 5),
#  ('Sydney, New South Wales', 4)]

# %%
most_user_locations = pd.DataFrame(most_common_locations, columns=[['location','count']])
most_user_locations
# Out:
#                           location count
# 0                                    485
# 1                    United States    24
# 2                  Los Angeles, CA    15
# 3                            Earth    10
# 4                      New Zealand     9
# 5                           Canada     9
# 6                  New Jersey, USA     9
# 7      Vancouver, British Columbia     8
# 8                              USA     7
# 9         Your Motherboard's house     6
# 10  Earth Between Mexico & Canada      6
# 11                       Australia     6
# 12                 California, USA     6
# 13                    Florida, USA     5
# 14                   Michigan, USA     5
# 15                          London     5
# 16    Harrow  and Brighton England     5
# 17                   New York City     5
# 18                              UK     5
# 19         Sydney, New South Wales     4

# %%
# tweet metadata
tweets = spark.sql('''
                        SELECT
                            id_str as tweet_unique_id,
                            lang as tweet_lang,
                            full_text as tweet_text
                        FROM
                            df
                        WHERE 
                            retweeted_status.id_str IS NULL
                                ''')

# %%
tweets.printSchema()
# Out:
# root
#  |-- tweet_unique_id: string (nullable = true)
#  |-- tweet_lang: string (nullable = true)
#  |-- tweet_text: string (nullable = true)

# %%
tweets.show(5)
# Out:
# +-------------------+----------+--------------------+
# |    tweet_unique_id|tweet_lang|          tweet_text|
# +-------------------+----------+--------------------+
# |1577080692164657152|        en|in this @NRDC pie...|
# |1577080684321046528|        en|Nowhere is comple...|
# |1577080675122876417|        en|@GerberKawasaki @...|
# |1577080637399261184|        en|sometimes i wonde...|
# |1577080632097677312|        en|Drought and clima...|
# +-------------------+----------+--------------------+
# only showing top 5 rows

# %%
tweets.count()
# Out:
# 1292

# %%
tweets_df = tweets.toPandas()

# %%
# check 'tweet_lang' unique count
tweets_df['tweet_lang'].nunique()
# Out:
# 11

# %%
# show 'tweet_lang' values
tweets_df['tweet_lang'].unique()
# Out:
# array(['en', 'und', 'pt', 'ja', 'fr', 'tl', 'es', 'it', 'sv', 'ca', 'ar'],
#       dtype=object)

# %%
# remove 'tweet_lang' != 'en'
tweets_df = tweets_df[tweets_df['tweet_lang'] == 'en']

# %%
sample_tweets = tweets_df.copy()

# %%
sample_tweets.head()
# Out:
#        tweet_unique_id tweet_lang  \
# 0  1577080692164657152         en
# 1  1577080684321046528         en
# 2  1577080675122876417         en
# 3  1577080637399261184         en
# 4  1577080632097677312         en
#
#                                           tweet_text
# 0  in this @NRDC piece: “the IPCC does not even a...
# 1  Nowhere is completely safe from #climatechange...
# 2  @GerberKawasaki @elonmusk Many fear everything...
# 3  sometimes i wonder if these water &amp; hurric...
# 4  Drought and climate change are changing the wa...

# %%
sample_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1239 entries, 0 to 1291
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tweet_unique_id  1239 non-null   object
#  1   tweet_lang       1239 non-null   object
#  2   tweet_text       1239 non-null   object
# dtypes: object(3)
# memory usage: 38.7+ KB

# %%
# tweet[0] before preprocessing for reference
sample_tweets['tweet_text'][0]
# Out:
# 'in this @NRDC piece: “the IPCC does not even assess, let alone support, the use of forest #bioenergy and BECCS as a climate solution and has not determined that biomass is essential to addressing #climatechange.” https://t.co/0E5ps1hIEw\n\nIf that’s not enough, you can read it in'

# %%
# remove urls
sample_tweets['converted_tweets'] = sample_tweets['tweet_text'].apply(lambda x: re.sub('htt\S+', '', x))

# %%
# remove punctuation and lowercase text
sample_tweets['converted_tweets'] = sample_tweets['converted_tweets'].apply(lambda x: re.sub('[^\w\s]', ' ', x)).str.lower()

# %%
# tweet[0] after preprocessing
sample_tweets['converted_tweets'][0]
# Out:
# 'in this  nrdc piece   the ipcc does not even assess  let alone support  the use of forest  bioenergy and beccs as a climate solution and has not determined that biomass is essential to addressing  climatechange   \n\nif that s not enough  you can read it in'

# %%
# vader sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# apply method to cleaned text, add new column
sample_tweets['score'] = sample_tweets['converted_tweets'].apply(analyzer.polarity_scores).apply(lambda x: x.get('compound'))

# %%
sample_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1239 entries, 0 to 1291
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tweet_unique_id   1239 non-null   object
#  1   tweet_lang        1239 non-null   object
#  2   tweet_text        1239 non-null   object
#  3   converted_tweets  1239 non-null   object
#  4   score             1239 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 90.4+ KB

# %%
sample_tweets['sentiment'] = sample_tweets['score'].apply(lambda x: 'Positive' if x > 0.0 else 'Negative' if x < 0.0 else 'Neutral')

# %%
sample_tweets.head()
# Out:
#        tweet_unique_id tweet_lang  \
# 0  1577080692164657152         en
# 1  1577080684321046528         en
# 2  1577080675122876417         en
# 3  1577080637399261184         en
# 4  1577080632097677312         en
#
#                                           tweet_text  \
# 0  in this @NRDC piece: “the IPCC does not even a...
# 1  Nowhere is completely safe from #climatechange...
# 2  @GerberKawasaki @elonmusk Many fear everything...
# 3  sometimes i wonder if these water &amp; hurric...
# 4  Drought and climate change are changing the wa...
#
#                                     converted_tweets   score sentiment
# 0  in this  nrdc piece   the ipcc does not even a...  0.2415  Positive
# 1  nowhere is completely safe from  climatechange... -0.8782  Negative
# 2   gerberkawasaki  elonmusk many fear everything... -0.6249  Negative
# 3  sometimes i wonder if these water  amp  hurric... -0.6369  Negative
# 4  drought and climate change are changing the wa... -0.0964  Negative

# %%
for item in range(0,700,100):
    print(item)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600

# %%
plt.figure(figsize = (12,8))
plt.title('Tweet Sentiment Distribution',fontsize = 20)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

ax = sns.countplot(x=sample_tweets['sentiment'])
ax.set(xlabel=None)
ax.set(ylabel=None)

# plt.savefig('../04_data_visualizations/tweet_sentiment_distribution.png', transparent=True)

plt.show();
