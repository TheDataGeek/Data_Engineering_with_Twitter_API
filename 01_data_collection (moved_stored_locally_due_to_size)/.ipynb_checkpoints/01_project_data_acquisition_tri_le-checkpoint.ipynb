# %% [markdown]
# # check conda environment

# %%
conda info
# Out:
#      active environment : None
#        user config file : /home/jovyan/.condarc
#  populated config files : /opt/conda/.condarc
#           conda version : 4.13.0
#     conda-build version : not installed
#          python version : 3.10.5.final.0
#        virtual packages : __linux=5.10.124=0
#                           __glibc=2.35=0
#                           __unix=0=0
#                           __archspec=1=x86_64
#        base environment : /opt/conda  (writable)
#       conda av data dir : /opt/conda/etc/conda
#   conda av metadata url : None
#            channel URLs : https://conda.anaconda.org/conda-forge/linux-64
#                           https://conda.anaconda.org/conda-forge/noarch
#           package cache : /opt/conda/pkgs
#                           /home/jovyan/.conda/pkgs
#        envs directories : /opt/conda/envs
#                           /home/jovyan/.conda/envs
#                platform : linux-64
#              user-agent : conda/4.13.0 requests/2.28.1 CPython/3.10.5 Linux/5.10.124-linuxkit ubuntu/22.04.1 glibc/2.35
#                 UID:GID : 1000:100
#              netrc file : None
#            offline mode : False
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # pip install tweepy

# %%
# pip install tweepy

# %%
pip show tweepy
# Out:
# Name: tweepy
# Version: 4.10.1
# Summary: Twitter library for Python
# Home-page: https://www.tweepy.org/
# Author: Joshua Roesslein
# Author-email: tweepy@googlegroups.com
# License: MIT
# Location: /opt/conda/lib/python3.10/site-packages
# Requires: oauthlib, requests, requests-oauthlib
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # import libraries

# %%
import tweepy, logging, json, sys

# %% [markdown]
# # set up twitter API to collect tweets using tweepy

# %%
API_KEY = 'cUTS35r3qxKa9QKolTgYNRGrO'
API_SECRET = '0EL6zit7RT1rc7sxsOkm2ktsxbPY2f39GwHNMb2PRBqHuxJ7Xs'
BEARER_TOKEN = 'AAAAAAAAAAAAAAAAAAAAAPSBfQEAAAAA3i7%2F6yzdmBi80Cy6WwHar4LBCDs%3Dz5iTa6xXh9DILMuD1QdySguTQ4fqbp4ghYCdUejRLThAbeAkj9'

auth = tweepy.OAuth2AppHandler(API_KEY, API_SECRET)

api = tweepy.API(auth, wait_on_rate_limit=True, 
                 parser=tweepy.parsers.JSONParser())

if (not api):
    print('Failed Authentication')
    sys.exit(-1)

# %%
searchQuery = '''
                    (climate change) OR #climatechange OR 
                    (global warming) OR #globalwarming OR 
                    (climate crisis) OR #climatecrisis OR
                    (climate alarmist) OR (climate alarmists) OR
                    (climate denier) OR (climate deniers) OR
                    (climate skeptic) OR (climate skeptics) OR 
                    (climate skepticist) OR (climate skepticists)
                                                                    '''

# %%
sinceId = None
max_id = None
maxTweets = 2000000
tweetsPerQry = 100
tweetCount = 0
tweetFiles = 0
tweets = []
searchCount = 0

while 10000*tweetFiles + tweetCount < maxTweets:
    try:
        if (not max_id):
            if (not sinceId):
                new_tweets = api.search_tweets(q=searchQuery, 
                                               tweet_mode='extended',
                                               count=tweetsPerQry)
        
            else:
                new_tweets = api.search_tweets(q=searchQuery, 
                                               tweet_mode='extended',
                                               count = tweetsPerQry, 
                                               since_id = sinceId)

        else: 
            if (not sinceId):
                new_tweets = api.search_tweets(q=searchQuery, 
                                               tweet_mode='extended',
                                               count= tweetsPerQry, 
                                               max_id=str(max_id -1))

            else:
                new_tweets = api.search_tweets(q=searchQuery,
                                               tweet_mode='extended',
                                               count=tweetsPerQry, 
                                               max_id=str(max_id -1), 
                                               since_id=sinceId)    

        new_tweets = new_tweets['statuses']
            
        if len(new_tweets) == 0:
            msg = 'No remaining tweets found'
            logging.error(msg)
            break
        
        tweets.extend(new_tweets)
        tweetCount += len(new_tweets)
        msg = f'{tweetCount} tweets downloaded'
        logging.error(msg)
        max_id = new_tweets[-1]['id']
    
        if tweetCount >= 10000:
            with open('../01_data_collection/tweets'+str(tweetFiles)+'.json', 'w') as outfile:
                json.dump(tweets, outfile)
            msg = 'JSON file saved'
            logging.error(msg)
            tweetFiles += 1
            tweetCount = 0
            del tweets[:]
        
    except tweepy.errors.TweepyException as e:
        msg = f'Query failed at max_id {max_id} : {e}'
        logging.error(msg)

if tweetCount > 0:
    with open('../01_data_collection/tweets'+str(tweetFiles)+'.json', 'w') as outfile:
        json.dump(tweets, outfile)
    msg = 'JSON file saved'
    logging.error(msg)
    tweetFiles += 1
    tweetCount = 0
    del tweets[:]
# Out:
# ERROR:root:100 tweets downloaded
# ERROR:root:200 tweets downloaded
# ERROR:root:300 tweets downloaded
# ERROR:root:400 tweets downloaded
# ERROR:root:500 tweets downloaded
# ERROR:root:600 tweets downloaded
# ERROR:root:700 tweets downloaded
# ERROR:root:800 tweets downloaded
# ERROR:root:900 tweets downloaded
# ERROR:root:1000 tweets downloaded
# ERROR:root:1100 tweets downloaded
# ERROR:root:1200 tweets downloaded
# ERROR:root:1300 tweets downloaded
# ERROR:root:1400 tweets downloaded
# ERROR:root:1500 tweets downloaded
# ERROR:root:1600 tweets downloaded
# ERROR:root:1700 tweets downloaded
# ERROR:root:1800 tweets downloaded
# ERROR:root:1900 tweets downloaded
# ERROR:root:2000 tweets downloaded
# ERROR:root:2100 tweets downloaded
# ERROR:root:2200 tweets downloaded
# ERROR:root:2300 tweets downloaded
# ERROR:root:2400 tweets downloaded
# ERROR:root:2500 tweets downloaded
# ERROR:root:2600 tweets downloaded
# ERROR:root:2700 tweets downloaded
# ERROR:root:2800 tweets downloaded
# ERROR:root:2900 tweets downloaded
# ERROR:root:3000 tweets downloaded
# ERROR:root:3100 tweets downloaded
# ERROR:root:3200 tweets downloaded
# ERROR:root:3300 tweets downloaded
# ERROR:root:3400 tweets downloaded
# ERROR:root:3500 tweets downloaded
# ERROR:root:3600 tweets downloaded
# ERROR:root:3700 tweets downloaded
# ERROR:root:3800 tweets downloaded
# ERROR:root:3900 tweets downloaded
# ERROR:root:4000 tweets downloaded
# ERROR:root:4100 tweets downloaded
# ERROR:root:4200 tweets downloaded
# ERROR:root:4299 tweets downloaded
# ERROR:root:4399 tweets downloaded
# ERROR:root:4499 tweets downloaded
# ERROR:root:4599 tweets downloaded
# ERROR:root:4699 tweets downloaded
# ERROR:root:4799 tweets downloaded
# ERROR:root:4899 tweets downloaded
# ERROR:root:4999 tweets downloaded
# ERROR:root:5099 tweets downloaded
# ERROR:root:5199 tweets downloaded
# ERROR:root:5299 tweets downloaded
# ERROR:root:7700 tweets downloaded
# ERROR:root:7800 tweets downloaded
# ERROR:root:7900 tweets downloaded
# ERROR:root:8000 tweets downloaded
# ERROR:root:8100 tweets downloaded
# ERROR:root:8200 tweets downloaded
# ERROR:root:8300 tweets downloaded
# ERROR:root:8400 tweets downloaded
# ERROR:root:8500 tweets downloaded
# ERROR:root:8600 tweets downloaded
# ERROR:root:8700 tweets downloaded
# ERROR:root:8800 tweets downloaded
# ERROR:root:8900 tweets downloaded
# ERROR:root:9000 tweets downloaded
# ERROR:root:9100 tweets downloaded
# ERROR:root:9200 tweets downloaded
# ERROR:root:9300 tweets downloaded
# ERROR:root:9400 tweets downloaded
# ERROR:root:9500 tweets downloaded
# ERROR:root:9600 tweets downloaded
# ERROR:root:9700 tweets downloaded
# ERROR:root:9800 tweets downloaded
# ERROR:root:9900 tweets downloaded
# ERROR:root:10000 tweets downloaded
# ERROR:root:JSON file saved
# ERROR:root:100 tweets downloaded
# ERROR:root:200 tweets downloaded
# ERROR:root:300 tweets downloaded
# ERROR:root:400 tweets downloaded
# ERROR:root:500 tweets downloaded
# ERROR:root:600 tweets downloaded
# ERROR:root:700 tweets downloaded
# ERROR:root:800 tweets downloaded
# ERROR:root:900 tweets downloaded
# ERROR:root:1000 tweets downloaded
# ERROR:root:1100 tweets downloaded
# ERROR:root:1200 tweets downloaded
# ERROR:root:1300 tweets downloaded
# ERROR:root:1400 tweets downloaded
# ERROR:root:1500 tweets downloaded
# ERROR:root:1600 tweets downloaded
# ERROR:root:1700 tweets downloaded
# ERROR:root:1800 tweets downloaded
# ERROR:root:1900 tweets downloaded
# ERROR:root:2000 tweets downloaded
# ERROR:root:2100 tweets downloaded
# ERROR:root:2200 tweets downloaded
# ERROR:root:2300 tweets downloaded
# ERROR:root:2400 tweets downloaded
# ERROR:root:2500 tweets downloaded
# ERROR:root:2600 tweets downloaded
# ERROR:root:2700 tweets downloaded
# ERROR:root:2800 tweets downloaded
# ERROR:root:2900 tweets downloaded
# ERROR:root:3000 tweets downloaded
# ERROR:root:3100 tweets downloaded
# ERROR:root:3200 tweets downloaded
# ERROR:root:3300 tweets downloaded
# ERROR:root:3400 tweets downloaded
# ERROR:root:3500 tweets downloaded
# ERROR:root:3600 tweets downloaded
# ERROR:root:3700 tweets downloaded
# ERROR:root:3800 tweets downloaded
# ERROR:root:3900 tweets downloaded
# ERROR:root:4000 tweets downloaded
# ERROR:root:4100 tweets downloaded
# ERROR:root:4200 tweets downloaded
# ERROR:root:4300 tweets downloaded
# ERROR:root:4400 tweets downloaded
# ERROR:root:4500 tweets downloaded
# ERROR:root:4600 tweets downloaded
# ERROR:root:4700 tweets downloaded
# ERROR:root:4800 tweets downloaded
# WARNING:tweepy.api:Rate limit reached. Sleeping for: 667

# %%
with open(f'../01_data_collection/tweets1.json') as json_file:
    data=json.load(json_file)

# %%
len(data)

# %%
total_observations = 0
for num in range(0,5):
    with open(f'../01_data_collection/tweets{num}.json') as json_file:
        data=json.load(json_file)
    total_observations += len(data)
    print(total_observations)
